# %%
import pandas as pd
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /home/dl6/anaconda3/envs/tf-gpu/lib/python3.8/site-packages (4.4.0.46)
# Requirement already satisfied: numpy>=1.17.3 in /home/dl6/anaconda3/envs/tf-gpu/lib/python3.8/site-packages (from opencv-python) (1.19.2)

# %%
import os
import cv2

for i in range (0,105): 
    # create folder to store extracted images
   
    os.mkdir('videoframes/Frames_video'+ str(i))
    #extract video
    vidcap = cv2.VideoCapture('/home/dl6/deep-learning-team6/WS2020_DeepLearning_Videos/Task1_Training_Validation/_8Vy3dlHg2w_00' + str(i).zfill(3)+ '.mp4')
    count = 0
    
    while True:
        success,image = vidcap.read()
        if not success:
            break
         # save frame as JPG file
        cv2.imwrite(os.path.join(folder,"frame{:d}.jpg".format(count)), image)  
        count += 1
    print(str(count) + ' images are extacted in video ' + str(i))
# Out:
# 76 images are extacted in video 0
# 88 images are extacted in video 1
# 89 images are extacted in video 2
# 95 images are extacted in video 3
# 87 images are extacted in video 4
# 76 images are extacted in video 5
# 45 images are extacted in video 6
# 87 images are extacted in video 7
# 112 images are extacted in video 8
# 88 images are extacted in video 9
# 67 images are extacted in video 10
# 103 images are extacted in video 11
# 65 images are extacted in video 12
# 0 images are extacted in video 13
# 88 images are extacted in video 14
# 59 images are extacted in video 15
# 0 images are extacted in video 16
# 95 images are extacted in video 17
# 48 images are extacted in video 18
# 85 images are extacted in video 19
# 92 images are extacted in video 20
# 50 images are extacted in video 21
# 0 images are extacted in video 22
# 0 images are extacted in video 23
# 87 images are extacted in video 24
# 68 images are extacted in video 25
# 82 images are extacted in video 26
# 60 images are extacted in video 27
# 88 images are extacted in video 28
# 0 images are extacted in video 29
# 61 images are extacted in video 30
# 0 images are extacted in video 31
# 0 images are extacted in video 32
# 93 images are extacted in video 33
# 66 images are extacted in video 34
# 71 images are extacted in video 35
# 69 images are extacted in video 36
# 0 images are extacted in video 37
# 0 images are extacted in video 38
# 77 images are extacted in video 39
# 60 images are extacted in video 40
# 0 images are extacted in video 41
# 69 images are extacted in video 42
# 128 images are extacted in video 43
# 192 images are extacted in video 44
# 71 images are extacted in video 45
# 95 images are extacted in video 46
# 37 images are extacted in video 47
# 49 images are extacted in video 48
# 43 images are extacted in video 49
# 96 images are extacted in video 50
# 76 images are extacted in video 51
# 82 images are extacted in video 52
# 113 images are extacted in video 53
# 102 images are extacted in video 54
# 0 images are extacted in video 55
# 110 images are extacted in video 56
# 43 images are extacted in video 57
# 53 images are extacted in video 58
# 60 images are extacted in video 59
# 0 images are extacted in video 60
# 240 images are extacted in video 61
# 129 images are extacted in video 62
# 68 images are extacted in video 63
# 0 images are extacted in video 64
# 56 images are extacted in video 65
# 101 images are extacted in video 66
# 110 images are extacted in video 67
# 0 images are extacted in video 68
# 56 images are extacted in video 69
# 52 images are extacted in video 70
# 64 images are extacted in video 71
# 105 images are extacted in video 72
# 67 images are extacted in video 73
# 70 images are extacted in video 74
# 110 images are extacted in video 75
# 149 images are extacted in video 76
# 87 images are extacted in video 77
# 66 images are extacted in video 78
# 0 images are extacted in video 79
# 56 images are extacted in video 80
# 59 images are extacted in video 81
# 116 images are extacted in video 82
# 0 images are extacted in video 83
# 139 images are extacted in video 84
# 65 images are extacted in video 85
# 0 images are extacted in video 86
# 55 images are extacted in video 87
# 132 images are extacted in video 88
# 83 images are extacted in video 89
# 93 images are extacted in video 90
# 114 images are extacted in video 91
# 61 images are extacted in video 92
# 95 images are extacted in video 93
# 105 images are extacted in video 94
# 81 images are extacted in video 95
# 89 images are extacted in video 96
# 74 images are extacted in video 97
# 101 images are extacted in video 98
# 67 images are extacted in video 99
# 111 images are extacted in video 100
# 138 images are extacted in video 101
# 47 images are extacted in video 102
# 93 images are extacted in video 103
# 108 images are extacted in video 104
