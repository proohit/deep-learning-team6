# %%
import pandas as pd

# %%
import os
import cv2

for i in range (0,105): 
    # create folder to store extracted images
    folder = 'videoframes/Frames_video'+ str(i)
    os.mkdir(folder)
    #extract video
    vidcap = cv2.VideoCapture('/home/dl6/deep-learning-team6/1b/trainingvideos/_8Vy3dlHg2w_00' + str(i).zfill(3)+ '.mp4')
    count = 0
    while True:
        success,image = vidcap.read()
        if not success:
            break
        cv2.imwrite(os.path.join(folder,"frame{:d}.jpg".format(count)), image)  
        count += 1
    print(str(count) + ' images are extacted in video ' + str(i))
# Out:
# 76 images are extacted in video 0
# 88 images are extacted in video 1
# 89 images are extacted in video 2
# 95 images are extacted in video 3
# 87 images are extacted in video 4
# 76 images are extacted in video 5
# 45 images are extacted in video 6
# 87 images are extacted in video 7
# 112 images are extacted in video 8
# 88 images are extacted in video 9
# 67 images are extacted in video 10
# 103 images are extacted in video 11
# 65 images are extacted in video 12
# 56 images are extacted in video 13
# 88 images are extacted in video 14
# 59 images are extacted in video 15
# 58 images are extacted in video 16
# 95 images are extacted in video 17
# 48 images are extacted in video 18
# 85 images are extacted in video 19
# 92 images are extacted in video 20
# 50 images are extacted in video 21
# 67 images are extacted in video 22
# 104 images are extacted in video 23
# 87 images are extacted in video 24
# 68 images are extacted in video 25
# 82 images are extacted in video 26
# ...

# %%
videoframe_num={}
size_all = 0
for i in range(0,105): 
    traindata= os.listdir('/home/dl6/deep-learning-team6/1b/videoframes/Frames_video'+ str(i))
    
    videoframe_num['video'+str(i)]=len(traindata)
    
    size_all+=len(traindata)
    
    print('video ' +str(i)+ ' has ' + str(videoframe_num['video'+str(i)]) + ' images')
    
print('sum of images:' + str(size_all))
# Out:
# video 0 has 76 images
# video 1 has 88 images
# video 2 has 89 images
# video 3 has 95 images
# video 4 has 87 images
# video 5 has 76 images
# video 6 has 45 images
# video 7 has 87 images
# video 8 has 112 images
# video 9 has 88 images
# video 10 has 67 images
# video 11 has 103 images
# video 12 has 65 images
# video 13 has 56 images
# video 14 has 88 images
# video 15 has 59 images
# video 16 has 58 images
# video 17 has 95 images
# video 18 has 48 images
# video 19 has 85 images
# video 20 has 92 images
# video 21 has 50 images
# video 22 has 67 images
# video 23 has 104 images
# video 24 has 87 images
# video 25 has 68 images
# video 26 has 82 images
# video 27 has 60 images
# video 28 has 88 images
# video 29 has 79 images
# video 30 has 61 images
# video 31 has 103 images
# video 32 has 127 images
# video 33 has 93 images
# video 34 has 66 images
# video 35 has 71 images
# video 36 has 69 images
# video 37 has 101 images
# video 38 has 90 images
# video 39 has 77 images
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as ig

plt.figure()
img = ig.imread('/home/dl6/deep-learning-team6/1b/videoframes/Frames_video10/frame44.jpg')
imgplot= plt.imshow(img)

# %%
imgplot = plt.imshow(img)
lum_img = img[:, :, 0]



plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
# delete folder 

#import shutil

#for i in range (0,105): 
#   shutil.rmtree('videoframes/Frames_video'+ str(i))
