# %%
import pandas as pd
def get_csv_data(video_folder_name, fileName):    
    data = pd.read_csv(fileName, sep=';')
    data.columns = ['ID', 'file_name', 'label']
    file_paths = []
    for entry in data.iloc():
        file_paths.append(video_folder_name + entry['file_name'])
    data['file_path'] = file_paths
    data.set_index('ID', inplace=True, drop=False)
    return data

training = get_csv_data('../WS2020_DeepLearning_Videos/Task1_Training_Validation/', '../Task1_Training_Labels_Videos.csv')
test = get_csv_data('../WS2020_DeepLearning_Videos/Task1_Test/', '../Task1_Test_Labels_Videos.csv')

display(training)
display(test)
# Out:
#       ID              file_name      label  \
# ID
# 1      1  _8Vy3dlHg2w_00000.mp4       Side
# 2      2  _8Vy3dlHg2w_00001.mp4    Upwards
# 3      3  _8Vy3dlHg2w_00002.mp4      Front
# 4      4  _8Vy3dlHg2w_00003.mp4       Side
# 5      5  _8Vy3dlHg2w_00004.mp4  Downwards
# ..   ...                    ...        ...
# 96    96  _8Vy3dlHg2w_00100.mp4      Front
# 97    97  _8Vy3dlHg2w_00101.mp4       Side
# 98    98  _8Vy3dlHg2w_00102.mp4       Side
# 99    99  _8Vy3dlHg2w_00103.mp4      Front
# 100  100  _8Vy3dlHg2w_00104.mp4       Side
#
#                                              file_path
# ID
# 1    ../WS2020_DeepLearning_Videos/Task1_Training_V...
# 2    ../WS2020_DeepLearning_Videos/Task1_Training_V...
# 3    ../WS2020_DeepLearning_Videos/Task1_Training_V...
# 4    ../WS2020_DeepLearning_Videos/Task1_Training_V...
# 5    ../WS2020_DeepLearning_Videos/Task1_Training_V...
# ..                                                 ...
# 96   ../WS2020_DeepLearning_Videos/Task1_Training_V...
# 97   ../WS2020_DeepLearning_Videos/Task1_Training_V...
# 98   ../WS2020_DeepLearning_Videos/Task1_Training_V...
# 99   ../WS2020_DeepLearning_Videos/Task1_Training_V...
# 100  ../WS2020_DeepLearning_Videos/Task1_Training_V...
#
# [100 rows x 4 columns]
#     ID              file_name      label  \
# ID
# 1    1  _8Vy3dlHg2w_00105.mp4       Side
# 2    2  _8Vy3dlHg2w_00106.mp4      Front
# 3    3  _8Vy3dlHg2w_00108.mp4  Downwards
# 4    4  _8Vy3dlHg2w_00109.mp4      Front
# 5    5  _8Vy3dlHg2w_00110.mp4       Side
# 6    6  _8Vy3dlHg2w_00111.mp4       Side
# 7    7  _8Vy3dlHg2w_00112.mp4      Front
# 8    8  _8Vy3dlHg2w_00113.mp4       Side
# 9    9  _8Vy3dlHg2w_00114.mp4  Downwards
# 10  10  _8Vy3dlHg2w_00115.mp4      Front
# 11  11  _8Vy3dlHg2w_00116.mp4       Side
# 12  12  _8Vy3dlHg2w_00117.mp4  Downwards
# 13  13  _8Vy3dlHg2w_00118.mp4       Side
# 14  14  _8Vy3dlHg2w_00120.mp4  Downwards
# 15  15  _8Vy3dlHg2w_00121.mp4      Front
# 16  16  _8Vy3dlHg2w_00122.mp4       Side
# 17  17  _8Vy3dlHg2w_00123.mp4      Front
# 18  18  _8Vy3dlHg2w_00124.mp4  Downwards
# 19  19  _8Vy3dlHg2w_00125.mp4       Side
# 20  20  _8Vy3dlHg2w_00126.mp4      Front
# 21  21  _8Vy3dlHg2w_00127.mp4       Side
# 22  22  _8Vy3dlHg2w_00128.mp4      Front
# 23  23  _8Vy3dlHg2w_00129.mp4       Side
# 24  24  _8Vy3dlHg2w_00130.mp4       Side
#
#                                             file_path
# ID
# 1   ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 2   ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 3   ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 4   ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 5   ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 6   ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 7   ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 8   ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 9   ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 10  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 11  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 12  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 13  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 14  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 15  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 16  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 17  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 18  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 19  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 20  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 21  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 22  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 23  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...
# 24  ../WS2020_DeepLearning_Videos/Task1_Test/_8Vy3...

# %%
def encode_position(label):
    if label == 'Side':
        return 0
    if label == 'Front':
        return 1
    if label == 'Upwards':
        return 2
    if label == 'Downwards':
        return 3

# %%
import cv2
import numpy as np
class_names = ['Side', 'Front', 'Upwards', 'Downwards']
def get_frames_labels(data, frames, labels):
    for file in data.iloc():
        file_path = file['file_path']
        video_id = file['ID']
        label = encode_position(data.loc[video_id].label)
        
        # Playing video from file:
        cap = cv2.VideoCapture(file['file_path'])
        success, frame = cap.read()

        while(success):
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame = cv2.resize(frame, (256,256))
            frames.append(frame)
            labels.append(label)
            # Capture frame by frame
            success, frame = cap.read()

        cap.release()
        cv2.destroyAllWindows()
        # Remove this break when accessing all video files
        
training_frames = []
training_labels = []
test_frames = []
test_labels = []
get_frames_labels(training, training_frames, training_labels)
get_frames_labels(test, test_frames, test_labels)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

train_images = np.array(training_frames)
train_labels = np.array(training_labels)
test_images = np.array(test_frames)
test_labels = np.array(test_labels)

print(train_images.shape)
print(test_images.shape)
display(train_labels)
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i]])
plt.show()
# Out:
# (7008, 256, 256, 3)
# (2238, 256, 256, 3)
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from tensorflow.keras import layers, models, regularizers
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256,256, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(4))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 254, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 125, 64)      18496
# _________________________________________________________________
# flatten (Flatten)            (None, 1000000)           0
# _________________________________________________________________
# dense (Dense)                (None, 64)                64000064
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 64,019,716
# Trainable params: 64,019,716
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 219/219 [==============================] - 7s 33ms/step - loss: 235.7817 - accuracy: 0.9018 - val_loss: 0.0881 - val_accuracy: 0.9607
# Epoch 2/10
# 219/219 [==============================] - 7s 32ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0212 - val_accuracy: 0.9942
# Epoch 3/10
# 219/219 [==============================] - 7s 32ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.0629 - val_accuracy: 0.9687
# Epoch 4/10
# 219/219 [==============================] - 7s 32ms/step - loss: 0.1242 - accuracy: 0.9812 - val_loss: 0.0176 - val_accuracy: 0.9933
# Epoch 5/10
# 219/219 [==============================] - 7s 32ms/step - loss: 0.6451 - accuracy: 0.9345 - val_loss: 0.1519 - val_accuracy: 0.9598
# Epoch 6/10
# 219/219 [==============================] - 7s 32ms/step - loss: 0.0515 - accuracy: 0.9919 - val_loss: 0.3216 - val_accuracy: 0.9522
# Epoch 7/10
# 219/219 [==============================] - 7s 32ms/step - loss: 0.0339 - accuracy: 0.9909 - val_loss: 0.1804 - val_accuracy: 0.9701
# Epoch 8/10
# 219/219 [==============================] - 7s 32ms/step - loss: 0.0136 - accuracy: 0.9977 - val_loss: 0.1479 - val_accuracy: 0.9660
# Epoch 9/10
# 219/219 [==============================] - 7s 32ms/step - loss: 0.2575 - accuracy: 0.9418 - val_loss: 0.3830 - val_accuracy: 0.8727
# Epoch 10/10
# 219/219 [==============================] - 7s 32ms/step - loss: 0.1350 - accuracy: 0.9521 - val_loss: 0.2058 - val_accuracy: 0.9459

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 70/70 - 1s - loss: 0.2058 - accuracy: 0.9459

# %% [markdown]
# 1. Input Video handling
# 2. Layer anpassen

# %%
from functools import reduce
def predict_video(path):
    # Playing video from file:
    images_of_video = []
    cap = cv2.VideoCapture(path)
    success, frame = cap.read()

    while(success):
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = cv2.resize(frame, (256,256))
        images_of_video.append(frame)
        # Capture frame by frame
        success, frame = cap.read()
    cap.release()
    cv2.destroyAllWindows()
    
    images_of_video = np.array(images_of_video)
    
    predictions = model.predict(images_of_video)
    
    predictions = tf.nn.softmax(predictions)
    
    predicted_labels = [class_names[np.argmax(prediction)] for prediction in predictions]
    
    most_frequent_label = max(set(predicted_labels), key = predicted_labels.count)
    
    frequent_label_index = class_names.index(most_frequent_label)
    
    mean_score = 0
    for prediction in predictions:
        score = prediction
        mean_score += score[frequent_label_index]
    mean_score = mean_score / len(predictions)
    
    print(
        """
         File: {} 
         predicted perspective: {} 
         confidence: {:.2f}%
         """
        .format(path, most_frequent_label, 100 * mean_score)
    )
    


predict_video('../WS2020_DeepLearning_Videos/Task2_Test/_tigfCJFLZg_00314.mp4')
# Out:
#          File: ../WS2020_DeepLearning_Videos/Task2_Test/_tigfCJFLZg_00314.mp4
#          predicted perspective: Side
#          confidence: 78.33%

# %%
import os

video_folder = "../WS2020_DeepLearning_Videos/Task2_Test/"
for root, dirs, files in os.walk(video_folder):
    for filename in files:
        if '.mp4' in filename:
            predict_video(f"{video_folder}/{filename}")
# Out:
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00351.mp4
#          predicted perspective: Side
#          confidence: 81.17%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00317.mp4
#          predicted perspective: Side
#          confidence: 68.13%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00374.mp4
#          predicted perspective: Side
#          confidence: 90.89%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00377.mp4
#          predicted perspective: Side
#          confidence: 70.19%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00354.mp4
#          predicted perspective: Side
#          confidence: 72.31%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00328.mp4
#          predicted perspective: Side
#          confidence: 67.53%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00359.mp4
#          predicted perspective: Side
#          confidence: 77.25%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00303.mp4
#          predicted perspective: Side
#          confidence: 72.93%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00357.mp4
#          predicted perspective: Side
#          confidence: 76.40%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00431.mp4
#          predicted perspective: Side
#          confidence: 98.00%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00353.mp4
#          predicted perspective: Side
#          confidence: 69.89%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00372.mp4
#          predicted perspective: Side
#          confidence: 65.40%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00389.mp4
#          predicted perspective: Side
#          confidence: 72.68%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00348.mp4
#          predicted perspective: Side
#          confidence: 68.35%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00332.mp4
#          predicted perspective: Side
#          confidence: 65.01%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00309.mp4
#          predicted perspective: Side
#          confidence: 66.66%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00311.mp4
#          predicted perspective: Side
#          confidence: 63.13%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00344.mp4
#          predicted perspective: Side
#          confidence: 65.18%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00425.mp4
#          predicted perspective: Side
#          confidence: 68.19%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00393.mp4
#          predicted perspective: Side
#          confidence: 73.95%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00326.mp4
#          predicted perspective: Side
#          confidence: 85.75%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00324.mp4
#          predicted perspective: Side
#          confidence: 75.36%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00369.mp4
#          predicted perspective: Side
#          confidence: 66.13%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00380.mp4
#          predicted perspective: Side
#          confidence: 68.00%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00338.mp4
#          predicted perspective: Side
#          confidence: 76.09%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00347.mp4
#          predicted perspective: Side
#          confidence: 69.04%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00416.mp4
#          predicted perspective: Side
#          confidence: 58.24%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00430.mp4
#          predicted perspective: Side
#          confidence: 68.58%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00409.mp4
#          predicted perspective: Side
#          confidence: 54.52%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00298.mp4
#          predicted perspective: Side
#          confidence: 74.89%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00329.mp4
#          predicted perspective: Side
#          confidence: 79.21%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00411.mp4
#          predicted perspective: Side
#          confidence: 74.17%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00370.mp4
#          predicted perspective: Side
#          confidence: 68.60%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00392.mp4
#          predicted perspective: Side
#          confidence: 73.22%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00407.mp4
#          predicted perspective: Side
#          confidence: 77.21%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00423.mp4
#          predicted perspective: Side
#          confidence: 69.34%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00413.mp4
#          predicted perspective: Side
#          confidence: 80.30%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00433.mp4
#          predicted perspective: Side
#          confidence: 94.52%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00312.mp4
#          predicted perspective: Side
#          confidence: 73.01%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00419.mp4
#          predicted perspective: Upwards
#          confidence: 34.89%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00408.mp4
#          predicted perspective: Side
#          confidence: 70.87%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00321.mp4
#          predicted perspective: Side
#          confidence: 81.46%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00304.mp4
#          predicted perspective: Side
#          confidence: 81.67%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00435.mp4
#          predicted perspective: Side
#          confidence: 68.59%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00429.mp4
#          predicted perspective: Side
#          confidence: 76.57%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00356.mp4
#          predicted perspective: Side
#          confidence: 82.82%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00376.mp4
#          predicted perspective: Side
#          confidence: 75.34%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00417.mp4
#          predicted perspective: Side
#          confidence: 76.07%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00366.mp4
#          predicted perspective: Side
#          confidence: 82.38%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00402.mp4
#          predicted perspective: Side
#          confidence: 75.97%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00305.mp4
#          predicted perspective: Side
#          confidence: 64.37%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00420.mp4
#          predicted perspective: Side
#          confidence: 76.15%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00360.mp4
#          predicted perspective: Side
#          confidence: 83.63%
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00330.mp4
#          predicted perspective: Side
#          confidence: 79.58%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00327.mp4
#          predicted perspective: Side
#          confidence: 75.03%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00337.mp4
#          predicted perspective: Side
#          confidence: 86.67%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00320.mp4
#          predicted perspective: Side
#          confidence: 86.19%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00384.mp4
#          predicted perspective: Side
#          confidence: 79.32%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00345.mp4
#          predicted perspective: Side
#          confidence: 74.08%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00414.mp4
#          predicted perspective: Side
#          confidence: 79.63%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00398.mp4
#          predicted perspective: Side
#          confidence: 74.46%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00323.mp4
#          predicted perspective: Side
#          confidence: 63.40%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00367.mp4
#          predicted perspective: Side
#          confidence: 77.79%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00406.mp4
#          predicted perspective: Side
#          confidence: 79.95%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00319.mp4
#          predicted perspective: Side
#          confidence: 71.60%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00302.mp4
#          predicted perspective: Side
#          confidence: 69.51%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00379.mp4
#          predicted perspective: Side
#          confidence: 81.68%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00400.mp4
#          predicted perspective: Side
#          confidence: 69.02%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00333.mp4
#          predicted perspective: Side
#          confidence: 71.29%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00386.mp4
#          predicted perspective: Side
#          confidence: 64.09%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00403.mp4
#          predicted perspective: Side
#          confidence: 68.84%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00428.mp4
#          predicted perspective: Side
#          confidence: 67.56%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00395.mp4
#          predicted perspective: Side
#          confidence: 79.23%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00422.mp4
#          predicted perspective: Side
#          confidence: 69.63%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00361.mp4
#          predicted perspective: Side
#          confidence: 79.80%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00301.mp4
#          predicted perspective: Side
#          confidence: 81.96%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00390.mp4
#          predicted perspective: Side
#          confidence: 68.33%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00350.mp4
#          predicted perspective: Side
#          confidence: 81.86%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00313.mp4
#          predicted perspective: Side
#          confidence: 63.77%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00295.mp4
#          predicted perspective: Side
#          confidence: 77.89%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00436.mp4
#          predicted perspective: Side
#          confidence: 78.46%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00299.mp4
#          predicted perspective: Side
#          confidence: 72.78%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00385.mp4
#          predicted perspective: Side
#          confidence: 74.70%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00381.mp4
#          predicted perspective: Side
#          confidence: 89.21%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00342.mp4
#          predicted perspective: Side
#          confidence: 71.37%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00314.mp4
#          predicted perspective: Side
#          confidence: 78.33%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00383.mp4
#          predicted perspective: Side
#          confidence: 74.75%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00358.mp4
#          predicted perspective: Side
#          confidence: 81.81%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00293.mp4
#          predicted perspective: Side
#          confidence: 75.03%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00340.mp4
#          predicted perspective: Side
#          confidence: 65.52%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00308.mp4
#          predicted perspective: Side
#          confidence: 76.09%
#
#
#          File: ../WS2020_DeepLearning_Videos/Task2_Test//_tigfCJFLZg_00387.mp4
#          predicted perspective: Side
#          confidence: 76.33%

# %%
from tensorflow.keras import backend as K


def show_layer_for_image(layer, image):
    my_image = test_images[image]
    my_image_raw = np.squeeze(my_image)
    image = np.expand_dims(my_image, axis=0)
    layer = model.get_layer(index = layer)
    print(type(layer).__name__)
    convolutions = K.function(model.inputs, [layer.output])([image])
    #kick out empty axes
    convolutions = np.squeeze(convolutions)
    #rearange the order so that we can iterate over the images
    convolutions = np.transpose(convolutions)
    width = 33
    fig = plt.figure(figsize=(100, 100))
    # draw the original pic first
    ax = fig.add_subplot(1, width, 1)
    ax.axis('off')
    ax.title.set_text("Original")
    ax.imshow(my_image_raw, interpolation='sinc' , cmap='binary')
    # draw some examples for filter results
    for index, filter in enumerate(convolutions):
        if index == width - 1:
            break
        ax = fig.add_subplot(1, width, index + 2)
        ax.axis('off')
        ax.title.set_text(index)
        ax.imshow(filter.transpose(), interpolation = 'sinc', cmap='binary')
    plt.show()
    plt.close()
show_layer_for_image(0, 180)
show_layer_for_image(1, 180)
show_layer_for_image(2, 180)
# Out:
# Conv2D
# MaxPooling2D
# Conv2D
